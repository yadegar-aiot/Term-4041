# %% [markdown]
# <div style="text-align: center;">
# <img
#   src="../../assets/IOT-LOGO-Blue.svg"
#   alt="IOT-LOGO-Blue"
#   loading="lazy"
#   onerror="https://github.com/yadegar-aiot/.github/blob/main/profile%2Fassets%2FIOT-LOGO-Blue.svg"
#   width="400" alt="test"
# />
#
#  <!-- <img src="../../assets/IOT-LOGO-Blue.svg" width="280" alt="AI & IoT SSA logo"> -->
#
# </div>
#
# <div dir="rtl" style="text-align: center;">
# <h1>
# انجمن علمی دانشجویی
# IOT
# و هوش مصنوعی
# </h1>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h1 style="margin:0;">
# برگه تمرین‌های چالشی پایتون (جلسه آخر)</h1><br><span class="muted">
# این برگه فقط از مطالب گفته‌شده در جزوه‌های شما استفاده می‌کند؛ هدفش فکر کردن و حل مسئله است، نه حفظ کردن.</span><br>
# <div class="box"><b>مشخصات دانشجو (برای صدور گواهی)</b>
# <br>نام و نام خانوادگی:
#  <span style="display:inline-block;min-width:260px;border-bottom:1px solid #000;">&nbsp;</span>
# <br>کد ملی:
# <span style="display:inline-block;min-width:260px;border-bottom:1px solid #000;">&nbsp;</span><br>کد دانشجویی: <span style="display:inline-block;min-width:260px;border-bottom:1px solid #000;">&nbsp;</span></div></div>

# %%
"""مشخصات خواسته شده را در اینجا در قالب داک استرینگ بنویسید"""

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">قوانین انجام تمرین</h2><br>۱) از هیچ موضوعی خارج از جزوه استفاده نکنید (مثلاً <code class="ltr">set</code>، <code class="ltr">sorted</code>، <code class="ltr">min</code> و ...).<br>۲) تا جای ممکن راه‌حل را «تابع‌محور» بنویسید: ورودی گرفتن جدا، پردازش جدا، چاپ نتیجه جدا.<br>۳) برای ورودی‌های کاربر، مدیریت خطا را با <code class="ltr">try/except</code> انجام دهید.<br>۴) برای تست، چند ورودی مختلف امتحان کنید (مرزی/عجیب/غلط).<br><blockquote><b>یادآوری:</b> <code class="ltr">print</code> فقط نمایش می‌دهد؛ برای خروجی واقعی تابع از <code class="ltr">return</code> استفاده کنید.</blockquote></div>

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">بخش ۱) شرط و حلقه‌ها</h2><br><b>تمرین ۱:</b> عدد <code class="ltr">n</code> را از کاربر بگیر. از ۱ تا <code class="ltr">n</code> چاپ کن، با این قانون:<br>اگر عدد مضرب ۳ بود <span class="ltr">Fizz</span>، اگر مضرب ۵ بود <span class="ltr">Buzz</span>، اگر هر دو بود <span class="ltr">FizzBuzz</span>، وگرنه خود عدد.<br><span class="muted">راهنما: از <code class="ltr">for</code> و شرط‌های <code class="ltr">if/elif/else</code> استفاده کن.</span></div>

# %%
# تمرین ۱
# TODO: کد را اینجا بنویس

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><b>تمرین ۲:</b> برنامه‌ای بنویس که «فقط وقتی ورودی درست است» ادامه بدهد: از کاربر یک عدد صحیح غیرمنفی بگیر و فاکتوریل آن را حساب کن.<br>اگر کاربر عدد نامعتبر داد یا منفی داد، پیام مناسب بده و دوباره درخواست کن.<br><span class="muted">راهنما: یک حلقه <code class="ltr">while True</code> + <code class="ltr">try/except ValueError</code> + شرط منفی/غیرمنفی.</span></div>

# %%
# تمرین ۲
# TODO: کد را اینجا بنویس

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><b>تمرین ۳:</b> تابع <code class="ltr">is_prime(n)</code> بنویس که تشخیص بدهد عدد اول هست یا نه. سپس با یک حلقه، همهٔ اعداد اول بین ۲ تا ۱۰۰ را چاپ کن.<br><span class="muted">راهنما: در تابع، با <code class="ltr">for</code> مقسوم‌علیه‌ها را چک کن و اگر پیدا شد از <code class="ltr">return False</code> استفاده کن.</span></div>

# %%
# تمرین ۳
def is_prime(n):
    # TODO: پیاده‌سازی
    pass

# TODO: چاپ اعداد اول 2 تا 100

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><b>تمرین ۴:</b> یک عدد <code class="ltr">height</code> بگیر و یک «مثلث عددی» بساز: خط اول 1، خط دوم 12، خط سوم 123، ... تا ارتفاع داده‌شده.<br><span class="muted">راهنما: با حلقه تو در تو و ساختن یک رشته (با الحاق) انجام بده.</span><br><blockquote><b>خطاهای رایج این بخش:</b> اشتباه در تورفتگی (Indentation)، شرط‌های ناقص، حلقه بی‌نهایت در <code class="ltr">while</code>، اشتباه یک‌واحدی (Off-by-one) در <code class="ltr">range</code>.</blockquote></div>

# %%
# تمرین ۴
# TODO: کد را اینجا بنویس

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">بخش ۲) لیست و تاپل</h2><br><b>تمرین ۵:</b> یک لیست از اعداد بساز (یا از کاربر بگیر). بدون استفاده از <code class="ltr">min</code> و <code class="ltr">max</code>، کمترین و بیشترین مقدار را با حلقه پیدا کن و خروجی را به صورت یک تاپل <code class="ltr">(min_value, max_value)</code> برگردان.<br><span class="muted">راهنما: مقدار اولیه را از عنصر اول لیست بگیر و سپس با حلقه مقایسه کن.</span></div>

# %%
# تمرین ۵
numbers = [12, 3, 44, 9, 44, -2, 10]
# TODO: کمینه و بیشینه را با حلقه پیدا کن

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><b>تمرین ۶:</b> حذف تکراری‌ها با حفظ ترتیب: از لیست زیر یک لیست جدید بساز که فقط اولین رخداد هر عدد را نگه دارد.<br><span class="muted">محدودیت: از <code class="ltr">set</code> استفاده نکن. فقط از لیست و شرط <code class="ltr">in</code> استفاده کن.</span></div>

# %%
# تمرین ۶
data = [5, 1, 5, 2, 1, 3, 2, 4, 5]
# TODO: unique_list بساز

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><b>تمرین ۷:</b> چرخش لیست به راست: لیست <code class="ltr">data</code> و عدد <code class="ltr">k</code> داده شده. لیست را k خانه به راست بچرخان (مثلاً k=2 یعنی دو عنصر آخر بیایند جلو).<br><span class="muted">راهنما: از برش (Slicing) استفاده کن. (مثلاً <code class="ltr">data[-k:]</code> و <code class="ltr">data[:-k]</code>)</span></div>

# %%
# تمرین ۷
data = [1, 2, 3, 4, 5, 6]
k = 2
# TODO: لیست چرخیده را بساز و چاپ کن

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><b>تمرین ۸:</b> تابع <code class="ltr">split_even_odd(nums)</code> بنویس که یک لیست بگیرد و دو لیست برگرداند: یکی زوج‌ها و یکی فردها. خروجی تابع باید یک تاپل شامل دو لیست باشد.<br><span class="muted">راهنما: با <code class="ltr">append</code> به لیست‌ها اضافه کن.</span><br><blockquote><b>خطاهای رایج این بخش:</b> دسترسی اشتباه به اندیس‌ها (IndexError)، اشتباه گرفتن «کپی» و «ارجاع» (Aliasing)، فراموش کردن مقداردهی اولیه لیست خروجی.</blockquote></div>

# %%
# تمرین ۸
def split_even_odd(nums):
    # TODO: پیاده‌سازی
    pass

print(split_even_odd([1, 2, 3, 4, 5, 6]))

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">بخش ۳) حلقه‌های کاربردی‌تر: enumerate و zip</h2><br><b><span class="ltr">enumerate</span> چرا مهم است؟</b> وقتی هم «اندیس» می‌خواهیم هم «خود مقدار»، به جای شمارنده دستی، از <code class="ltr">enumerate</code> استفاده می‌کنیم.<br>الگو: <code class="ltr">for idx, value in enumerate(my_list, start=0):</code><br><b><span class="ltr">zip</span> چرا مهم است؟</b> وقتی می‌خواهیم همزمان روی چند لیست حرکت کنیم (مثل نام‌ها و نمره‌ها)، از <code class="ltr">zip</code> استفاده می‌کنیم.<br>الگو: <code class="ltr">for a, b in zip(list1, list2):</code><br><blockquote><b>خطاهای رایج:</b> قاطی کردن <code class="ltr">idx</code> با مقدار واقعی، و این نکته که <code class="ltr">zip</code> به اندازه کوتاه‌ترین لیست جلو می‌رود.</blockquote></div>

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><b>تمرین ۹:</b> با <code class="ltr">enumerate</code> روی لیست زیر حرکت کن و فقط عنصرهایی را چاپ کن که «اندیس‌شان زوج است». خروجی باید به شکل <code class="ltr">index -> value</code> باشد.</div>

# %%
# تمرین ۹
items = ["a", "b", "c", "d", "e", "f", "g"]
# TODO: با enumerate فقط اندیس‌های زوج را چاپ کن

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><b>تمرین ۱۰:</b> دو لیست زیر را با <code class="ltr">zip</code> ترکیب کن و یک دیکشنری بساز که نام هر نفر، نمرهٔ او باشد. سپس میانگین نمره‌ها را چاپ کن (بدون استفاده از <code class="ltr">min</code> و ...).</div>

# %%
# تمرین ۱۰
names = ["Ali", "Sara", "Reza", "Nika"]
scores = [18, 20, 15, 19]
# TODO: dict بساز و میانگین را حساب کن

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">بخش ۴) دیکشنری</h2><br><b>تمرین ۱۱:</b> دفترچه تلفن: یک دیکشنری خالی بساز. در یک حلقه از کاربر «نام» و «شماره» بگیر و ذخیره کن. اگر کاربر <span class="ltr">exit</span> زد، حلقه تمام شود و در پایان همهٔ مخاطب‌ها را چاپ کن.<br><span class="muted">راهنما: برای چاپ از <code class="ltr">for name, phone in phonebook.items():</code> استفاده کن.</span></div>

# %%
# تمرین ۱۱
phonebook = {}
# TODO: با حلقه ورودی بگیر و ذخیره کن

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><b>تمرین ۱۲:</b> شمارش رقم‌ها: یک رشته از کاربر بگیر. فقط تعداد رقم‌های 0 تا 9 را بشمار (حروف و بقیه چیزها مهم نیست). خروجی یک دیکشنری باشد.<br><span class="muted">راهنما: از <code class="ltr">dict.get(key, 0)</code> استفاده کن و با حلقه روی رشته حرکت کن.</span></div>

# %%
# تمرین ۱۲
text = input("یک متن بده: ")
# TODO: digit_counts بساز

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><b>تمرین ۱۳:</b> گروه‌بندی معکوس: یک دیکشنری <code class="ltr">student_to_score</code> داریم. یک دیکشنری جدید بساز که کلیدش «نمره» و مقدارش «لیست دانشجوها» باشد. (مثلاً 20 -> ["Sara", "Nika"])<br><span class="muted">راهنما: مقدار اولیهٔ لیست را با <code class="ltr">get</code> بساز یا اگر نبود ایجاد کن، سپس <code class="ltr">append</code> کن.</span><br><blockquote><b>خطاهای رایج این بخش:</b> استفاده از کلید ناموجود و گرفتن <code class="ltr">KeyError</code>، فراموش کردن ساخت لیست برای هر کلید، اشتباه گرفتن <code class="ltr">items()</code> با <code class="ltr">values()</code>.</blockquote></div>

# %%
# تمرین ۱۳
student_to_score = {"Ali": 18, "Sara": 20, "Reza": 18, "Nika": 20, "Mina": 15}
# TODO: score_to_students بساز

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">بخش ۵) مدیریت خطا با try/except</h2><br><b>تمرین ۱۴:</b> تابع <code class="ltr">get_int(prompt)</code> بنویس که تا وقتی کاربر عدد صحیح درست وارد نکرده، دوباره سؤال بپرسد. سپس با آن، دو عدد بگیر و تقسیمشان را چاپ کن (تقسیم بر صفر را هم مدیریت کن).</div>

# %%
# تمرین ۱۴
def get_int(prompt):
    # TODO: پیاده‌سازی با while و try/except
    pass

a = get_int("عدد اول: ")
b = get_int("عدد دوم: ")
# TODO: تقسیم را انجام بده و خطاهای ValueError و ZeroDivisionError را مدیریت کن

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><b>تمرین ۱۵:</b> یک لیست ثابت داریم. از کاربر اندیس بگیر و عنصر آن اندیس را چاپ کن. خطاهای ورودی غلط و خارج از محدوده را مدیریت کن.<br><blockquote><b>خطاهای رایج این بخش:</b> گرفتن <code class="ltr">except</code> خیلی کلی، نخواندن پیام خطا (Traceback)، و برعکس گرفتن نوع خطا (ValueError vs IndexError).</blockquote></div>

# %%
# تمرین ۱۵
data = [10, 20, 30, 40, 50]
# TODO: اندیس را بگیر و عنصر را چاپ کن؛ ValueError و IndexError را مدیریت کن

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">بخش ۶) کار با کتابخانه‌ها</h2><br><b>تمرین ۱۶:</b> شبیه‌سازی تاس: از کتابخانه <code class="ltr">random</code> و تابع <code class="ltr">randint</code> استفاده کن. هر بار یک عدد 1 تا 6 تولید کن تا وقتی مجموع تاس‌ها به یک هدف (target) برسد یا از آن رد شود. تعداد پرتاب‌ها و مجموع نهایی را چاپ کن.<br><span class="muted">راهنما: target را با <code class="ltr">get_int</code> بگیر تا ورودی درست باشد.</span></div>

# %%
# تمرین ۱۶
from random import randint

# TODO: کد شبیه‌سازی را اینجا بنویس

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><b>تمرین ۱۷:</b> فاصله دو نقطه: با <code class="ltr">import math</code> و <code class="ltr">math.sqrt</code> تابع <code class="ltr">distance(p1, p2)</code> بنویس. ورودی‌ها دو تاپل مثل <code class="ltr">(x, y)</code> هستند. خروجی فاصله اقلیدسی باشد.<br><span class="muted">فرمول: <code class="ltr">sqrt((x2-x1)**2 + (y2-y1)**2)</code></span><br><blockquote><b>خطاهای رایج این بخش:</b> فراموش کردن <code class="ltr">import</code>، اشتباه در اسم ماژول/تابع، و استفاده از متغیرهای اشتباه (x1/x2).</blockquote></div>

# %%
# تمرین ۱۷
import math

def distance(p1, p2):
    # TODO: پیاده‌سازی
    pass

print(distance((0, 0), (3, 4)))  # انتظار: 5

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">بخش ۷) پروژهٔ کوچک (تابع‌محور)</h2><br><b>پروژه:</b> «سیستم نمره‌دهی ساده» بساز که این قابلیت‌ها را داشته باشد:<br>۱) افزودن/به‌روزرسانی نمره یک دانشجو (نام → نمره) در دیکشنری<br>۲) نمایش همه دانشجوها و نمره‌ها<br>۳) محاسبه و نمایش میانگین نمره‌ها<br>۴) خروج با گزینه 0<br><br><b>قانون:</b> منو را در یک حلقه اجرا کن و هر کار را داخل یک تابع جدا بنویس.<br><span class="muted">پیشنهاد توابع: <code class="ltr">add_or_update(db)</code>، <code class="ltr">show_all(db)</code>، <code class="ltr">average(db)</code>، <code class="ltr">menu()</code></span><br><blockquote><b>خطاهای رایج این بخش:</b> قاطی کردن <code class="ltr">print</code> و <code class="ltr">return</code>، استفاده از متغیرهای سراسری بدون نیاز، و مدیریت نکردن ورودی‌های غلط.</blockquote></div>

# %%
# پروژه پایانی
# TODO: توابع را بنویس و منو را اجرا کن

db = {}

def add_or_update(db):
    # TODO
    pass

def show_all(db):
    # TODO
    pass

def average(db):
    # TODO
    pass

# TODO: حلقه منو

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">چک‌لیست قبل از تحویل</h2><br>✅ کد بدون خطای نحوی اجرا می‌شود.<br>✅ برای ورودی‌های غلط، برنامه کرش نمی‌کند و پیام مناسب می‌دهد.<br>✅ خروجی‌ها واضح و خوانا هستند.<br>✅ کد تا جای ممکن تابع‌محور و مرتب نوشته شده است.<br><br><div class="box"></div></div>
