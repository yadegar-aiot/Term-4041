# %%
print(50)
# Out:
# 50

# %%
print(50+2)
# Out:
# 52

# %%
print(سلام)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(سلام)
#
# NameError: name 'سلام' is not defined

# %%
print("hello world")
# Out:
# hello world

# %%
5+6
# Out:
# 11

# %%
1
# Out:
# 1

# %%
2
# Out:
# 2

# %%
1.54646546564
# Out:
# 1.54646546564

# %%
5+4
# Out:
# 9

# %%
5-4
# Out:
# 1

# %%
5*4
# Out:
# 20

# %%
20/4
# Out:
# 5.0

# %%
19 / 4
# Out:
# 4.75

# %%
19 // 4
# Out:
# 4

# %%
2**3
# Out:
# 8

# %%
34
# Out:
# 34

# %%
num1 = 4

# %%
num2 = 5

# %%
result = (num1+num2)//2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 result = (num1+num2)//2
#
# NameError: name 'num2' is not defined

# %%
print(result)
# Out:
# 4

# %%
name = "pooria"
fname = 'lari'
print(name, fname)
# Out:
# pooria lari

# %%
type(name)
# Out:
# str

# %%
type(fname)
# Out:
# str

# %%
type(num1)
# Out:
# int

# %%
type(num2)
# Out:
# int

# %%
fullname = input()

# %%
print(fullname)
# Out:
# ali

# %%
a = input()
b = input()
a = int(a)
b = int(b)
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 a = input()
#       2 b = input()
# ----> 3 a = int(a)
#       4 b = int(b)
#       5 print(a+b)
#
# ValueError: invalid literal for int() with base 10: 'afd'

# %%
type(a)
# Out:
# str

# %%
type(b)
# Out:
# str

# %% [markdown]
# ## int()

# %%
a = int("10")

# %%
a
# Out:
# 10

# %%
a = int(input("عدد اول را وارد نمایید"))
b = int(input("عدد دوم را وارد نمایید"))
print(a+b)
# Out:
# 17

# %%
name = input("نام خود را وارد کنید")

if name == "pooria":
    print("salam admin khosh omadi?!!!!!!")
else:
    print('salam user khosh omadi')


print("exit")
# Out:
# salam user khosh omadi
# exit

# %%
"Pooria" == "pooria"
# Out:
# False

# %%
"A" == "a"
# Out:
# False

# %%
"A" != "a"
# Out:
# True

# %% [markdown]
# Else if

# %% [markdown]
# type
# کاربر
# ادمینم
# اونر

# %%
name = input("نام خود را وارد کنید")

if name == "pooria":
    print("salam admin khosh omadi?!!!!!!")
elif name == "ali":
    print("salam ALI khosh omadi")
elif name == "Omid":
    print("salam omid khosh omadi")
else:
    print('salam user khosh omadi')


print("exit")
# Out:
# salam user khosh omadi
# exit

# %%
name = input("نام خود را وارد کنید")

if name == "pooria":
    print("salam admin khosh omadi?!!!!!!")
if name == "ali":
    print("salam ALI khosh omadi")
else:
    print('salam user khosh omadi')
if name == "pooria":
    print("salam admin khosh omadi?!!!!!!")
else:
    print('salam user khosh omadi')
# Out:
# salam user khosh omadi
# salam user khosh omadi

# %% [markdown]
# and / or

# %%
age = int(input("لطفا سنتونو وارد کنید"))

if age < 13:
    print('کودک')
elif age >= 13 and age < 20:
    print('نو جوان')
elif age >= 20 and age < 30:
    print("جوان")
elif age >= 30 and age < 40:
    print('بزرگسال')
elif age >= 40 :
    print("سالمند")
else:
    print("error")
# Out:
# سالمند

# %%
import gc
for _n in list(globals()):
    if not _n.startswith("_") and _n != "gc":
        del globals()[_n]
del _n
gc.collect()
# Out:
# 0
