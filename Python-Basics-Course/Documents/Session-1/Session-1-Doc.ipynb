# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
# <style>
# /* Persian / RTL-friendly rendering in Jupyter Notebook & JupyterLab */
# .rendered_html, .jp-RenderedHTMLCommon, .jp-MarkdownOutput {
#   direction: rtl;
#   text-align: right;
#   unicode-bidi: plaintext;
#   line-height: 1.9;
# }
# /* Make inline/code blocks & English segments stay LTR */
# code, pre, .ltr {
#   direction: ltr !important;
#   unicode-bidi: isolate;
#   text-align: left;
# }
# .ltr { display: inline-block; }
# </style>
#
#
# </div>

# %% [markdown]
# <div style="text-align: center;">
#   <img src="../../assets/IOT-LOGO-Blue.svg" width="280" alt="AI & IoT SSA logo">
# </div>
#
# <div dir="rtl" style="text-align: center;">
# <h1>
# انجمن علمی دانشجویی
# IOT
# و هوش مصنوعی
# </h1>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
# <div dir="rtl" style="text-align: right;">
#
# # جلسه ۱ — دوره مقدماتی پایتون (ویژه علاقه‌مندان به هوش مصنوعی)
# </div>
# <div dir="rtl" style="text-align: right; unicode-bidi: plaintext; line-height: 1.9;">
# <strong>هدف جلسه :</strong>
# آشنایی با محیط اجرای کد، نوشتن اولین برنامه‌ها، کامنت‌گذاری، چاپ خروجی، عملگرهای پایه، و درک مفهوم «متغیر» و «نوع داده».
#
# <blockquote dir="rtl" style="text-align: right; margin: 12px 0; padding: 10px 12px; border-right: 4px solid #8a8a8a; background: rgba(140,140,140,0.10);">
# نکته: این جزوه برای اجرای تعاملی در **Jupyter Notebook** نوشته شده است. برای اجرای هر سلول: <code class="ltr">Shift + Enter</code>.<br>
# </blockquote>
#
# </div>
#
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
# <div dir="rtl" style="text-align: right; unicode-bidi: plaintext; line-height: 1.9;">
#
# ## نحوه استفاده از نوت‌بوک
# - هر «سلول» می‌تواند متن (Markdown) یا کد (Code) باشد.
# - برای اجرای سلول کد: `Shift + Enter`
# - اگر کدی خطا داد، متن خطا را بخوانید؛ معمولاً دقیقاً می‌گوید مشکل کجاست.
#
# </div>
#
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
# <div dir="rtl" style="text-align: right; unicode-bidi: plaintext; line-height: 1.9;">
#
# ## اولین اجرای کد
#
# </div>
#
# </div>

# %%
print("سلام! به جلسه اول پایتون خوش آمدید 🌱")
# Out:
# سلام! به جلسه اول پایتون خوش آمدید 🌱

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
#   <h2 style="text-align: right;">
#     کامنت (<span class="ltr" dir="ltr">Comment</span>) چیست؟
#   </h2>
#
#   <p style="text-align: right;">
#     کامنت یعنی «یادداشت برای انسان‌ها». پایتون هنگام اجرا، کامنت را نادیده می‌گیرد.
#   </p>
#
#   <h3 style="text-align: right;">
#     ۱) کامنت تک‌خطی با <code class="ltr" dir="ltr">#</code>
#   </h3>
#
#   <p style="text-align: right;">
#     هر چیزی بعد از <code class="ltr" dir="ltr">#</code> تا انتهای همان خط، کامنت است.
#   </p>
#
#   <h3 style="text-align: right;">
#     ۲) رشتهٔ چندخطی با <code class="ltr" dir="ltr">""" ... """</code>
#   </h3>
#
#   <p style="text-align: right;">
#     این <strong>کامنت واقعی نیست</strong>؛ یک «رشتهٔ چندخطی» است.
#   </p>
#
#   <p style="text-align: right;">
#     اگر این رشته <strong>اولین خطِ داخل تابع/کلاس/فایل</strong> باشد،
#     به آن <span class="ltr" dir="ltr"><strong>Docstring</strong></span> می‌گویند
#     و برای مستندسازی رسمی کد استفاده می‌شود
#     (مثل <code class="ltr" dir="ltr">help()</code> و <code class="ltr" dir="ltr">__doc__</code>).
#   </p>
#
#   <blockquote
#     dir="rtl"
#     style="text-align: right; margin: 12px 0; padding: 10px 12px;
#            border-right: 4px solid #8a8a8a; background: rgba(140,140,140,0.10);">
#     <p style="text-align: right;">
#       نکته: برای توضیح چندخطیِ معمولی، بهتر است چند خط پشت‌سرهم
#       از <code class="ltr" dir="ltr">#</code> استفاده کنید؛
#       <code class="ltr" dir="ltr">""" ... """</code> را بیشتر برای
#       <span class="ltr" dir="ltr">Docstring</span> نگه دارید.
#     </p>
#   </blockquote>
#
# </div>
#
#
# </div>

# %%
# این یک کامنت است
print(55)  # این خط عدد 55 را چاپ می‌کند
# Out:
# 55

# %%
"""
این یک رشتهٔ چندخطی است.
اگر همینجا رها شود، معمولاً فقط یک مقدارِ بلااستفاده است.
برای توضیح چندخطیِ غیررسمی، بهتر است چند خط # بنویسیم.
"""

print("ادامهٔ برنامه")
# Out:
# ادامهٔ برنامه

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
# <div dir="rtl" style="text-align: right; unicode-bidi: plaintext; line-height: 1.9;">
#
# ### نمونهٔ Docstring داخل تابع
#
# </div>
#
# </div>

# %%
def jam(a, b):
    """دو عدد را جمع می‌کند و نتیجه را برمی‌گرداند."""
    return a + b

print(jam(3, 5))
print(jam.__doc__)
# Out:
# 8
# دو عدد را جمع می‌کند و نتیجه را برمی‌گرداند.

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
# ## دستور <code class="ltr">print</code>
# <div dir="rtl" style="text-align: right; unicode-bidi: plaintext; line-height: 1.9;">
# با <code class="ltr">print</code> می‌توانیم خروجی را در صفحه (کنسول/نوت‌بوک) نمایش دهیم.<br>
# چند نکته کاربردی:<br>
# - می‌توانیم چند مقدار را با هم چاپ کنیم.
# - می‌توانیم جداکننده (<code class="ltr">sep</code>) و پایان خط (<code class="ltr">end</code>) را تغییر دهیم.
#
# </div>
#
# </div>

# %%
print("عدد:", 10)
print("جمع:", 3 + 5)
print("سه مقدار:", 1, 2, 3)
# Out:
# عدد: 10
# جمع: 8
# سه مقدار: 1 2 3

# %%
print("الف", "ب", "پ", sep=" | ")
print("این جمله بدون رفتن به خط بعد", end=" ... ")
print("ادامه")
# Out:
# الف | ب | پ
# این جمله بدون رفتن به خط بعد ... ادامه

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
# <div dir="rtl" style="text-align: right;">
#
# ## عملگرهای محاسباتی (Operators)
# </div>
# <div dir="rtl" style="text-align: right; unicode-bidi: plaintext; line-height: 1.9;">
# عملگرهای رایج:<br>
#
# - جمع: `+`
# - تفریق: `-`
# - ضرب: `*`
# - تقسیم اعشاری: `/`
# - تقسیم صحیح: `//`
# - باقیمانده: `%`
# - توان: `**`
#
# <blockquote dir="rtl" style="text-align: right; margin: 12px 0; padding: 10px 12px; border-right: 4px solid #8a8a8a; background: rgba(140,140,140,0.10);">
# ترتیب انجام عملیات مثل ریاضی است: توان، ضرب/تقسیم، سپس جمع/تفریق. پرانتز همیشه اولویت دارد.<br>
# </blockquote>
#
# </div>
#
# </div>

# %%
print("3 + 5 =", 3 + 5)
print("10 - 4 =", 10 - 4)
print("6 * 7 =", 6 * 7)
print("10 / 4 =", 10 / 4)
print("10 // 4 =", 10 // 4)
print("10 % 4 =", 10 % 4)
print("2 ** 5 =", 2 ** 5)
# Out:
# 3 + 5 = 8
# 10 - 4 = 6
# 6 * 7 = 42
# 10 / 4 = 2.5
# 10 // 4 = 2
# 10 % 4 = 2
# 2 ** 5 = 32

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
# ## متغیر (Variable)
# <div dir="rtl" style="text-align: right; unicode-bidi: plaintext; line-height: 1.9;">
# متغیر یعنی «نامی که به یک مقدار اشاره می‌کند».<br>
# در پایتون لازم نیست از قبل نوع متغیر را مشخص کنید؛ نوع، از روی مقدار تعیین می‌شود.<br>
#
# ### قواعد نام‌گذاری متغیر
# - می‌تواند شامل حروف، عدد و زیرخط `_` باشد.
# - با عدد شروع نشود.
# - از نام‌های معنی‌دار استفاده کنید (مثل `sen` یا `avg` به جای `x1`).
#
# </div>
#
# </div>

# %%
sen = 20
name = "علی"
print("سن:", sen)
print("نام:", name)
# Out:
# سن: 20
# نام: علی

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
# ## نوع داده (Data Type)
# <div dir="rtl" style="text-align: right; unicode-bidi: plaintext; line-height: 1.9;">
# چند نوع داده‌ی پایه:<br>
#
# - `int` : عدد صحیح
# - `float` : عدد اعشاری
# - `str` : متن (رشته)
# - `bool` : درست/نادرست<br>
# با `type()` می‌توانیم نوع یک مقدار را ببینیم.<br>
#
# </div>
#
# </div>

# %%
print(type(10))
print(type(3.14))
print(type("سلام"))
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
# ## تبدیل نوع (Type Casting)
# <div dir="rtl" style="text-align: right; unicode-bidi: plaintext; line-height: 1.9;">
# گاهی لازم است نوع داده را تغییر دهیم:<br>
#
# - `int("12")` → 12
# - `float("3.5")` → 3.5
# - `str(100)` → "100"
#
# </div>
#
# </div>

# %%
a = "12"
print(a, type(a))
b = int(a)
print(b, type(b))
# Out:
# 12 <class 'str'>
# 12 <class 'int'>

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
# ## گرفتن ورودی از کاربر با <code class="ltr">input</code>
# <div dir="rtl" style="text-align: right; unicode-bidi: plaintext; line-height: 1.9;">
# تابع <code class="ltr">input()</code> همیشه خروجی را به صورت <strong>متن</strong> برمی‌گرداند، حتی اگر عدد وارد کنید.<br>
# پس برای محاسبات عددی باید آن را به `int` یا `float` تبدیل کنیم.<br>
#
# </div>
#
# </div>

# %%
# این سلول برای اجرا به ورودی نیاز دارد.
# در صورت نیاز اجرا کنید.

# x = input("یک عدد وارد کنید: ")
# print("نوع ورودی:", type(x))
# x = int(x)
# print("بعد از تبدیل:", x, type(x))

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
# <div dir="rtl" style="text-align: right; unicode-bidi: plaintext; line-height: 1.9;">
#
# ### مثال: جمع دو عددِ ورودی
#
# </div>
#
# </div>

# %%
# این سلول برای اجرا به ورودی نیاز دارد.
a = int(input("عدد اول: "))
b = int(input("عدد دوم: "))
print("جمع =", a + b)

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
# ## رشته‌ها (Strings)
# <div dir="rtl" style="text-align: right; unicode-bidi: plaintext; line-height: 1.9;">
# رشته یعنی متن. می‌توانیم با کوتیشن تکی `'...'` یا دوتایی `"..."` بنویسیم.<br>
# چند کار رایج:<br>
# - چسباندن رشته‌ها با `+`
# - طول رشته با `len`
# - تغییر حروف با `upper` و `lower` (برای متن انگلیسی بیشتر کاربرد دارد)
# - جایگزینی با `replace`
#
# </div>
#
# </div>

# %%
matn = "Python"
print(matn)
print("طول:", len(matn))
print("جایگزینی:", matn.replace("Py", "My"))
# Out:
# Python
# طول: 6
# جایگزینی: Mython

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
# ### قالب‌بندی متن (فاصله و ترکیب)
# <div dir="rtl" style="text-align: right; unicode-bidi: plaintext; line-height: 1.9;">
# برای چاپ مرتب، می‌توانیم چند مقدار را در <code class="ltr">print</code> کنار هم چاپ کنیم.<br>
# در مراحل بعد، با قالب‌بندی پیشرفته‌تر هم آشنا می‌شویم.<br>
#
# </div>
#
# </div>

# %%
name = "پوریا"
age = 24
print("نام:", name, "| سن:", age)
# Out:
# نام: پوریا | سن: 24

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
# <div dir="rtl" style="text-align: right; unicode-bidi: plaintext; line-height: 1.9;">
#
# ## خطاهای رایج مبتدی‌ها (و راه‌حل‌های سریع)<br>
#
# ### ۱) متن را بدون کوتیشن می‌نویسیم<br>
# - ❌ <code class="ltr">print(سلام)</code><br>
# - ✅ <code class="ltr">print("سلام")</code> یا <code class="ltr">print('سلام')</code><br>
#
# ### ۲) پرانتز را فراموش می‌کنیم (در پایتون ۳)<br>
# - ❌ <code class="ltr">print "سلام"</code><br>
# - ✅ <code class="ltr">print("سلام")</code><br>
#
# ### ۳) «دو نقطه» را آخرِ دستورهای بلوکی جا می‌اندازیم<br>
# این خطا معمولاً <span class="ltr">SyntaxError</span> می‌دهد.<br>
# - ❌ <code class="ltr">if x > 0</code><br>
# - ✅ <code class="ltr">if x > 0:</code><br>
#
# ### ۴) مشکل تورفتگی (Indentation)<br>
# پایتون با تورفتگی معنی بلوک را می‌فهمد؛ اگر تورفتگی درست نباشد، <span class="ltr">IndentationError</span> می‌گیرید.<br>
# - ✅ راه‌حل: همیشه از **Space** استفاده کنید (مثلاً 4 تا Space)، و قاطیِ <span class="ltr">Tab</span> و Space نکنید.<br>
#
# ### ۵) اشتباه گرفتن <code class="ltr">=</code> و <code class="ltr">==</code><br>
# - <code class="ltr">=</code> یعنی «انتساب» (قرار دادن مقدار)<br>
# - <code class="ltr">==</code> یعنی «مقایسه» (بررسی برابری)<br>
# - ❌ <code class="ltr">if x = 3:</code><br>
# - ✅ <code class="ltr">if x == 3:</code><br>
#
# ### ۶) فراموش می‌کنیم <code class="ltr">input()</code> همیشه رشته می‌دهد<br>
# این مورد معمولاً <span class="ltr">TypeError</span> می‌دهد.<br>
# - ❌ <code class="ltr">age = input("سن؟ "); print(age + 1)</code><br>
# - ✅ <code class="ltr">age = int(input("سن؟ ")); print(age + 1)</code><br>
#
# ### ۷) تبدیل نوعِ نامعتبر<br>
# این مورد معمولاً <span class="ltr">ValueError</span> می‌دهد.<br>
# - ❌ <code class="ltr">int("12a")</code><br>
# - ✅ اول بررسی کنید ورودی عددی باشد، یا پیام مناسب چاپ کنید.<br>
#
# ### ۸) نام‌گذاریِ بد (و سایه انداختن روی توابع آماده)<br>
# اگر اسم متغیر را <code class="ltr">print</code> یا <code class="ltr">input</code> یا <code class="ltr">list</code> بگذارید، بعداً دردسر می‌شود.<br>
# - ❌ <code class="ltr">print = 10</code><br>
# - ✅ <code class="ltr">count = 10</code> یا <code class="ltr">total = 10</code><br>
#
# ### ۹) اعداد فارسی / علائم فارسی در کد<br>
# پایتون برای عددها و بعضی علائم، نسخهٔ انگلیسی می‌خواهد.<br>
# - ❌ <code class="ltr">n = ۱۰</code>  (عدد فارسی)<br>
# - ✅ <code class="ltr">n = 10</code><br>
# - ❌ استفاده از <span class="ltr">،</span> به‌جای <span class="ltr">,</span> یا <span class="ltr">.</span><br>
#
# ### ۱۰) خطاهای رایج در لیست و دیکشنری (خیلی پرتکرار)<br>
# - <span class="ltr">IndexError</span>: اندیس خارج از محدودهٔ لیست<br>
#   - مثال: لیست 3تایی است ولی <code class="ltr">lst[3]</code> زده‌ای (یادت باشد از صفر شروع می‌شود).<br>
# - <span class="ltr">KeyError</span>: کلیدی در دیکشنری وجود ندارد<br>
#   - ✅ راه‌حل: قبل از دسترسی، چک کن <code class="ltr">if key in d:</code> یا از <code class="ltr">d.get(key)</code> استفاده کن.<br>
#
# ### چطور پیام خطا را بخوانیم؟ (مهارت نجات‌بخش)<br>
# 1) **آخرین خطِ خطا** معمولاً مهم‌ترین سرنخ است (نوع خطا مثل <span class="ltr">SyntaxError</span> یا <span class="ltr">TypeError</span>).<br>
# 2) به فلش <code class="ltr">^</code> نگاه کن؛ معمولاً نزدیک همان نقطه مشکل داری (پرانتز، کوتیشن، دو نقطه، …).<br>
# 3) اگر خطا مربوط به نوع داده بود، با <code class="ltr">type(x)</code> بررسی کن دقیقاً چه چیزی دستت است.<br>
#
# </div>
#
#
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
# ## تمرین‌های سریع (کلاس)
# <div dir="rtl" style="text-align: right; unicode-bidi: plaintext; line-height: 1.9;">
# ۱) عدد ۱۲۳ را چاپ کنید.<br>
# ۲) حاصل `7 * 8` را چاپ کنید.<br>
# ۳) دو متغیر `x=10` و `y=3` بسازید و `x // y` و `x % y` را چاپ کنید.<br>
# ۴) یک متغیر متنی بسازید و طول آن را چاپ کنید.<br>
#
# <blockquote dir="rtl" style="text-align: right; margin: 12px 0; padding: 10px 12px; border-right: 4px solid #8a8a8a; background: rgba(140,140,140,0.10);">
# راهنمایی: برای هر تمرین یک سلول کد جدا بنویسید.<br>
# </blockquote>
#
# </div>
#
# </div>

# %%
# تمرین ۱
print(123)
# Out:
# 123

# %%
# تمرین ۲
print(7 * 8)
# Out:
# 56

# %%
# تمرین ۳
x = 10
y = 3
print("تقسیم صحیح:", x // y)
print("باقیمانده:", x % y)
# Out:
# تقسیم صحیح: 3
# باقیمانده: 1

# %%
# تمرین ۴
s = "هوش مصنوعی"
print("طول متن:", len(s))
# Out:
# طول متن: 10

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
# ## تکلیف جلسه ۱ (خانه)<br>
# <div dir="rtl" style="text-align: right; unicode-bidi: plaintext; line-height: 1.9;">
# ۱) یک برنامه بنویسید که نام و سن کاربر را بگیرد و چاپ کند. (فعلاً به صورت متن چاپ شود.)<br>
# ۲) یک برنامه بنویسید که **قد (سانتی‌متر)** را بگیرد و به **متر** تبدیل کند و چاپ کند.<br>
# ۳) یک برنامه بنویسید که سه عدد را گرفته و میانگین آن‌ها را چاپ کند.<br>
#
# <blockquote dir="rtl" style="text-align: right; margin: 12px 0 0; padding: 10px 12px; border-right: 4px solid #8a8a8a; background: rgba(140,140,140,0.10);">
# نکته: برای تبدیل نوع از <code class="ltr">int</code> و <code class="ltr">float</code> استفاده کنید.<br>
# </blockquote>
#
# </div>
#
#
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
# # ادامه سرفصل‌ها — شرط‌ها، حلقه‌ها، لیست و دیکشنری<br>
# <div dir="rtl" style="text-align: right; unicode-bidi: plaintext; line-height: 1.9;">
# **هدف این بخش:** آماده‌سازی برای نوشتن برنامه‌های تصمیم‌گیر (شرط) و تکرارشونده (حلقه)، و ذخیره/مدیریت داده‌ها با لیست و دیکشنری.<br>
#
# <blockquote dir="rtl" style="text-align: right; margin: 12px 0; padding: 10px 12px; border-right: 4px solid #8a8a8a; background: rgba(140,140,140,0.10);">
# این بخش همان «ادامهٔ طبیعی» جلسه ۱ است؛ اگر زمان کلاس اجازه نداد، می‌توانید در خانه مطالعه کنید و تمرین‌ها را حل کنید.<br>
# </blockquote>
#
#
# </div>
#
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
# ## عملگرهای مقایسه‌ای (Comparison Operators)<br>
# <div dir="rtl" style="text-align: right; unicode-bidi: plaintext; line-height: 1.9;">
# در شرط‌ها معمولاً از عملگرهای مقایسه‌ای استفاده می‌کنیم. خروجی این عملگرها **بولی** است: `True` یا `False`.<br>
#
# - `==` برابر است؟<br>
# - `!=` نابرابر است؟<br>
# - `>` بزرگ‌تر از<br>
# - `<` کوچک‌تر از<br>
# - `>=` بزرگ‌تر یا مساوی<br>
# - `<=` کوچک‌تر یا مساوی<br>
#
#
# </div>
#
# </div>

# %%
# چند مقایسهٔ ساده
print(3 == 3)
print(3 != 3)
print(10 > 7)
print(10 <= 7)

# مقایسهٔ رشته‌ها (بر اساس ترتیب حروف/کد یونیکد)
print("apple" < "banana")
# Out:
# True
# False
# True
# False
# True

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
# ## ساختار شرطی `if / elif / else`<br>
# <div dir="rtl" style="text-align: right; unicode-bidi: plaintext; line-height: 1.9;">
# شرط یعنی «اگر این درست بود، آن کار را انجام بده».<br>
# در پایتون **تورفتگی (indentation)** بخشی از معنی برنامه است؛ یعنی بدنهٔ شرط باید با فاصله (معمولاً 4 اسپیس) جلوتر باشد.<br>
#
#
# </div>
#
# </div>

# %%
# مثال: تعیین وضعیت نمره
score = 67

if score >= 18:
    print("عالی ✅")
elif score >= 15:
    print("خوب 🙂")
elif score >= 10:
    print("قبول 😌")
else:
    print("مردود ❌")
# Out:
# عالی ✅

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
# ## عملگرهای منطقی `and / or / not` و مفهوم Truthy/Falsy<br>
# <div dir="rtl" style="text-align: right; unicode-bidi: plaintext; line-height: 1.9;">
# گاهی یک شرط از چند شرط کوچک‌تر ساخته می‌شود:<br>
# - `and` یعنی «هر دو باید درست باشند»<br>
# - `or` یعنی «حداقل یکی درست باشد»<br>
# - `not` یعنی «برعکس کن»<br>
# <br>
# در پایتون بعضی مقدارها «در حکم False» هستند (Falsy) مثل: `0` ، `""` ، `[]` ، `{}` ، `None`.<br>
# بقیهٔ مقدارها معمولاً «در حکم True» هستند (Truthy).<br>
#
#
# </div>
#
# </div>

# %%
print(True and False)
print(True or False)
print(not True)

# Truthy/Falsy
print(bool(0), bool(1))
print(bool(""), bool("سلام"))
print(bool([]), bool([1, 2]))
print(bool({}), bool({"a": 1}))
# Out:
# False
# True
# False
# False True
# False True
# False True
# False True

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
# ## حلقه `for` (تکرارِ شمارشی/روی داده‌ها)<br>
# <div dir="rtl" style="text-align: right; unicode-bidi: plaintext; line-height: 1.9;">
# حلقه یعنی «یک کار را چند بار تکرار کن».<br>
# پرکاربردترین حالت: تکرار روی یک بازه با `range`.<br>
#
#
# </div>
#
# </div>

# %%
# چاپ اعداد 0 تا 4
for i in range(5):
    print(i)

# جمع اعداد 1 تا 10
total = 0
for i in range(1, 11):
    total += i
print("جمع:", total)
# Out:
# 0
# 1
# 2
# 3
# 4
# جمع: 55

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
# ## حلقه `while` (تکرار تا وقتی شرط برقرار است)<br>
# <div dir="rtl" style="text-align: right; unicode-bidi: plaintext; line-height: 1.9;">
# `while` تا زمانی اجرا می‌شود که شرطش `True` باشد.<br>
# برای کنترل حلقه می‌توان از `break` (خروج فوری) و `continue` (رفتن به دور بعدی) استفاده کرد.<br>
#
#
# </div>
#
# </div>

# %%
# مثال: گرفتن ورودی تا وقتی کاربر "exit" بزند
while True:
    text = input("یک چیزی بنویس (برای خروج: exit): ")
    if text == "exit":
        break
    if text.strip() == "":
        continue
    print("شما نوشتید:", text)
# Out:
# شما نوشتید: run
# شما نوشتید: afda
# شما نوشتید: af
# شما نوشتید: ee

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
# ## لیست (List) — ذخیرهٔ چند مقدار به‌ترتیب<br>
# <div dir="rtl" style="text-align: right; unicode-bidi: plaintext; line-height: 1.9;">
# لیست‌ها برای نگه‌داشتن مجموعه‌ای از داده‌ها (به ترتیب) استفاده می‌شوند.<br>
# چند ابزار خیلی مهم:<br>
# - دسترسی با اندیس: `lst[0]` (اولین عضو) ، `lst[-1]` (آخرین عضو)<br>
# - طول لیست: `len(lst)`<br>
# - افزودن: `append`<br>
#
#
# </div>
#
# </div>

# %%
numbers = [10, 20, 30]
print(numbers[0], numbers[-1])
print("طول:", len(numbers))

numbers.append(40)
print("بعد از append:", numbers)

# پیمایش روی لیست
for n in numbers:
    print("عدد:", n)

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
# ## دیکشنری (Dictionary) — نگاشتِ کلید → مقدار<br>
# <div dir="rtl" style="text-align: right; unicode-bidi: plaintext; line-height: 1.9;">
# دیکشنری وقتی عالی است که بخواهیم با «کلید» به «مقدار» برسیم (مثل دفترچه مخاطب).<br>
# - ساخت: `{"key": value}`<br>
# - دسترسی: `d["key"]`<br>
# - روش امن‌تر برای خواندن: `d.get("key")` (اگر نبود، `None` می‌دهد)<br>
#
#
# </div>
#
# </div>

# %%
person = {"name": "Ali", "age": 22}
print(person["name"])
print(person.get("city"))  # وجود ندارد → None

# به‌روزرسانی/افزودن
person["city"] = "Tehran"
person["age"] += 1
print(person)

# پیمایش روی کلیدها و مقدارها
for k, v in person.items():
    print(k, "=>", v)

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
# <div dir="rtl" style="text-align: right; unicode-bidi: plaintext; line-height: 1.9;">
#
# ## تمرین‌های سریع (کلاس) — بخش شرط و حلقه<br>
# 1) یک عدد بگیر و بگو «مثبت/منفی/صفر» است.<br>
# 2) یک عدد بگیر و بگو «زوج/فرد» است.<br>
# 3) مجموع اعداد زوج بین ۱ تا ۱۰۰ را حساب کن.<br>
# 4) با `while` از کاربر عدد بگیر تا وقتی `0` وارد نکرده؛ سپس مجموع را چاپ کن.<br>
#
#
# </div>
#
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right; unicode-bidi: embed; line-height: 1.9;">
#
# <div dir="rtl" style="text-align: right; unicode-bidi: plaintext; line-height: 1.9;">
#
# ## تکلیف (خانه) — آمادگی جلسه بعد<br>
# - یک برنامه بنویس که از کاربر یک عدد `n` بگیرد و یک مثلث ستاره‌ای با ارتفاع `n` چاپ کند.<br>
# - یک دیکشنری بساز که نام چند درس و نمره‌شان را نگه دارد؛ میانگین نمره‌ها را حساب کن.<br>
#
# <blockquote dir="rtl" style="text-align: right; margin: 12px 0; padding: 10px 12px; border-right: 4px solid #8a8a8a; background: rgba(140,140,140,0.10);">
# نکته: برای ورودی‌ها یادت باشد <code class="ltr">input</code> رشته می‌دهد؛ اگر عدد می‌خواهی، تبدیل نوع لازم است (<code class="ltr">int</code> یا <code class="ltr">float</code>).<br>
# </blockquote>
#
#
# </div>
#
# </div>
