# %% [markdown]
# <div style="text-align: center;">
# <img
#   src="../../assets/IOT-LOGO-Blue.svg"
#   alt="IOT-LOGO-Blue"
#   loading="lazy"
#   onerror="https://github.com/yadegar-aiot/.github/blob/main/profile%2Fassets%2FIOT-LOGO-Blue.svg"
#   width="400" alt="test"
# />
#
#  <!-- <img src="../../assets/IOT-LOGO-Blue.svg" width="280" alt="AI & IoT SSA logo"> -->
#
# </div>
#
# <div dir="rtl" style="text-align: center;">
# <h1>
# انجمن علمی دانشجویی
# IOT
# و هوش مصنوعی
# </h1>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right; line-height:2;"><b>جلسه ۱ — دوره مقدماتی پایتون (ویژه علاقه‌مندان به هوش مصنوعی)</b><br>در این جلسه با پایه‌ترین مفاهیم پایتون شروع می‌کنیم: کامنت و داک‌استرینگ، <code class="ltr">print</code>، عملگرها، متغیرها، نوع داده‌ها، <code class="ltr">input</code>، رشته‌ها، و در پایان شرط‌ها و منطق پایه.<br></div>

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">نحوه استفاده از نوت‌بوک</h2></div><div dir="rtl" style="text-align:right; line-height:2;">این جزوه ترکیبی از «توضیح» و «کد» است.<br>برای هر بخش: (۱) متن را بخوانید، (۲) سلول کد زیرش را اجرا کنید، (۳) خروجی را بررسی کنید، (۴) اگر لازم بود مقدارها را تغییر دهید.<br><blockquote><b>نکته:</b> اجرای سلول‌ها از بالا به پایین انجام شود تا متغیرها درست در حافظه باشند.</blockquote></div>

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">اولین اجرای کد</h2></div><div dir="rtl" style="text-align:right; line-height:2;">هدف این بخش این است که مطمئن شویم محیط اجرا درست کار می‌کند و می‌توانیم خروجی بگیریم.<br></div>

# %%
print("سلام! به جلسه اول پایتون خوش آمدید 🌱")
# Out:
# سلام! به جلسه اول پایتون خوش آمدید 🌱

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">کامنت و Docstring</h2></div><div dir="rtl" style="text-align:right; line-height:2;">کامنت برای توضیح کد است و توسط پایتون اجرا نمی‌شود.<br><b>۱) کامنت تک‌خطی:</b> با <code class="ltr">#</code> تا آخر همان خط.<br><b>۲) رشتهٔ چندخطی:</b> با <code class="ltr">""" ... """</code> (این «کامنت» نیست؛ یک رشته است). اگر اولین خط داخل تابع/کلاس/فایل باشد، به آن <b>Docstring</b> می‌گوییم و در مستندسازی می‌آید (<code class="ltr">help()</code> و <code class="ltr">__doc__</code>).<br><b>خطاهای رایج این بخش:</b><br><ul><li>سه‌کوتیشن را کامل نمی‌بندیم ⇒ <code class="ltr">SyntaxError</code>.</li><li>از <code class="ltr">""" ... """</code> به‌جای کامنت چندخطی استفاده می‌کنیم؛ از نظر فنی «رشتهٔ بی‌استفاده» ساخته می‌شود و سبک خوبی نیست (برای توضیح چندخطی بهتر است چند خط <code class="ltr">#</code> بگذارید).</li><li>Docstring را وسط تابع می‌نویسیم؛ برای اینکه Docstring حساب شود باید اولین دستور داخل تابع/کلاس باشد.</li></ul></div>

# %%
# این یک کامنت است
print(55)  # این خط عدد 55 را چاپ می‌کند
# Out:
# 55

# %%
"""
این یک رشتهٔ چندخطی است.
اگر همینجا رها شود، معمولاً فقط یک مقدارِ بلااستفاده است.
برای توضیح چندخطیِ غیررسمی، بهتر است چند خط # بنویسیم.
"""

print("ادامهٔ برنامه")
# Out:
# ادامهٔ برنامه

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h3 style="margin:0;">نمونهٔ Docstring داخل تابع</h3></div><div dir="rtl" style="text-align:right; line-height:2;">در مثال زیر، رشتهٔ سه‌کوتیشنی به عنوان Docstringِ تابع ذخیره می‌شود و می‌توانیم آن را با <code class="ltr">__doc__</code> ببینیم.<br></div>

# %%
def jam(a, b):
    """دو عدد را جمع می‌کند و نتیجه را برمی‌گرداند."""
    return a + b

print(jam(3, 5))
print(jam.__doc__)
# Out:
# 8
# دو عدد را جمع می‌کند و نتیجه را برمی‌گرداند.

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">دستور print</h2></div><div dir="rtl" style="text-align:right; line-height:2;">تابع <code class="ltr">print</code> برای نمایش خروجی استفاده می‌شود.<br><b>نکته‌ها:</b> <code class="ltr">sep</code> جداکنندهٔ بین آیتم‌هاست و <code class="ltr">end</code> تعیین می‌کند آخر چاپ چه چیزی بیاید (پیش‌فرض رفتن به خط بعد است).<br><b>خطاهای رایج این بخش:</b><br><ul><li>در پایتون ۳ نوشتن <code class="ltr">print 10</code> غلط است؛ باید پرانتز داشته باشد.</li><li>می‌خواهیم عدد و متن را با <code class="ltr">+</code> بچسبانیم و <code class="ltr">TypeError</code> می‌گیریم؛ راه درست: جدا چاپ کردن (<code class="ltr">print("سن:", age)</code>) یا تبدیل به رشته (<code class="ltr">str(age)</code>).</li><li>فکر می‌کنیم <code class="ltr">sep</code> آخر خروجی هم می‌آید؛ در واقع فقط بین آیتم‌ها قرار می‌گیرد.</li></ul></div>

# %%
print("عدد:", 10)
print("جمع:", 3 + 5)
print("سه مقدار:", 1, 2, 3)
# Out:
# عدد: 10
# جمع: 8
# سه مقدار: 1 2 3

# %%
print("الف", "ب", "پ", sep=" | ")
print("این جمله بدون رفتن به خط بعد", end=" ... ")
print("ادامه")
# Out:
# الف | ب | پ
# این جمله بدون رفتن به خط بعد ... ادامه

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">عملگرهای محاسباتی</h2></div><div dir="rtl" style="text-align:right; line-height:2;">عملگرهای اصلی: جمع <code class="ltr">+</code>، تفریق <code class="ltr">-</code>، ضرب <code class="ltr">*</code>، تقسیم <code class="ltr">/</code>، تقسیم صحیح <code class="ltr">//</code>، باقیمانده <code class="ltr">%</code>، توان <code class="ltr">**</code>.<br><b>خطاهای رایج این بخش:</b><br><ul><li>انتظار داریم <code class="ltr">/</code> عدد صحیح بدهد؛ در پایتون همیشه خروجی <code class="ltr">float</code> است.</li><li>تقسیم بر صفر ⇒ <code class="ltr">ZeroDivisionError</code>.</li><li>ترتیب عملگرها را اشتباه می‌گیریم؛ در صورت شک از پرانتز استفاده کنید.</li><li>فرق <code class="ltr">/</code> و <code class="ltr">//</code> را قاطی می‌کنیم: اولی «تقسیم واقعی»، دومی «تقسیم صحیح» است.</li></ul></div>

# %%
print("3 + 5 =", 3 + 5)
print("10 - 4 =", 10 - 4)
print("6 * 7 =", 6 * 7)
print("10 / 4 =", 10 / 4)
print("10 // 4 =", 10 // 4)
print("10 % 4 =", 10 % 4)
print("2 ** 5 =", 2 ** 5)
# Out:
# 3 + 5 = 8
# 10 - 4 = 6
# 6 * 7 = 42
# 10 / 4 = 2.5
# 10 // 4 = 2
# 10 % 4 = 2
# 2 ** 5 = 32

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">متغیر</h2></div><div dir="rtl" style="text-align:right; line-height:2;">متغیر یعنی یک «نام» که به یک مقدار اشاره می‌کند.<br><b>قواعد نام‌گذاری:</b><br><ul><li>با عدد شروع نشود.</li><li>فاصله نداشته باشد (از <span class="ltr">_</span> استفاده کنید).</li><li>از کلمات رزروشده (مثل <span class="ltr">if</span>, <span class="ltr">for</span>) استفاده نکنید.</li></ul><b>خطاهای رایج این بخش:</b><br><ul><li>نام‌گذاری روی توابع آماده مثل <code class="ltr">list</code> یا <code class="ltr">sum</code> ⇒ بعداً گیج‌کننده می‌شود.</li><li>استفاده از اعداد/علائم فارسی در کد ⇒ خطاهای عجیب یا عدم اجرا.</li><li>اشتباه گرفتن <code class="ltr">=</code> (انتساب) و <code class="ltr">==</code> (مقایسه).</li></ul></div>

# %%
sen = 20
name = "علی"
print("سن:", sen)
print("نام:", name)
# Out:
# سن: 20
# نام: علی

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">نوع داده</h2></div><div dir="rtl" style="text-align:right; line-height:2;">چند نوع دادهٔ مهم: عدد صحیح (<code class="ltr">int</code>)، عدد اعشاری (<code class="ltr">float</code>)، متن (<code class="ltr">str</code>)، درست/نادرست (<code class="ltr">bool</code>).<br>می‌توانیم با <code class="ltr">type(x)</code> نوع را ببینیم.<br><b>خطاهای رایج این بخش:</b><br><ul><li>عدد را داخل کوتیشن می‌گذاریم و بعد انتظار محاسبه داریم: <code class="ltr">"10" + "2"</code> می‌شود <code class="ltr">"102"</code>.</li><li>مقایسهٔ رشته و عدد ⇒ <code class="ltr">TypeError</code>.</li></ul></div>

# %%
print(type(10))
print(type(3.14))
print(type("سلام"))
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">تبدیل نوع</h2></div><div dir="rtl" style="text-align:right; line-height:2;">گاهی لازم است نوع داده را تغییر دهیم: <code class="ltr">int("12")</code>، <code class="ltr">float("3.5")</code>، <code class="ltr">str(100)</code>.<br><b>خطاهای رایج این بخش:</b><br><ul><li><code class="ltr">int("12.5")</code> خطا می‌دهد؛ اول <code class="ltr">float</code> کنید یا ورودی را درست بگیرید.</li><li>ورودی با کاراکتر اضافی (مثل فاصله یا حروف) ⇒ <code class="ltr">ValueError</code>.</li><li><code class="ltr">int(3.9)</code> گرد نمی‌کند؛ فقط بخش اعشار را حذف می‌کند.</li></ul></div>

# %%
a = "12"
print(a, type(a))
b = int(a)
print(b, type(b))
# Out:
# 12 <class 'str'>
# 12 <class 'int'>

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">گرفتن ورودی با input</h2></div><div dir="rtl" style="text-align:right; line-height:2;">تابع <code class="ltr">input()</code> همیشه خروجی را به صورت <b>رشته</b> برمی‌گرداند؛ حتی اگر عدد وارد کنید.<br>پس برای محاسبات عددی معمولاً می‌نویسیم: <code class="ltr">int(input(...))</code> یا <code class="ltr">float(input(...))</code>.<br><b>خطاهای رایج این بخش:</b><br><ul><li>فراموش می‌کنیم ورودی رشته است و با آن جمع عددی انجام می‌دهیم ⇒ نتیجه غلط یا <code class="ltr">TypeError</code>.</li><li>کاربر عدد غیرمعتبر وارد می‌کند ⇒ <code class="ltr">ValueError</code> (با <code class="ltr">try/except</code> در جلسه‌های بعد کنترل می‌کنیم).</li></ul></div>

# %%
# این سلول برای اجرا به ورودی نیاز دارد.
# در صورت نیاز اجرا کنید.

# x = input("یک عدد وارد کنید: ")
# print("نوع ورودی:", type(x))
# x = int(x)
# print("بعد از تبدیل:", x, type(x))

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h3 style="margin:0;">مثال: جمع دو عددِ ورودی</h3></div><div dir="rtl" style="text-align:right; line-height:2;">در مثال زیر دو عدد را از کاربر می‌گیریم، به عدد تبدیل می‌کنیم، و جمع می‌زنیم.<br></div>

# %%
# این سلول برای اجرا به ورودی نیاز دارد.
a = int(input("عدد اول: "))
b = int(input("عدد دوم: "))
print("جمع =", a + b)

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">رشته‌ها</h2></div><div dir="rtl" style="text-align:right; line-height:2;">رشته یعنی متن؛ با کوتیشن تکی یا دوتایی ساخته می‌شود.<br>کارهای رایج: چسباندن با <code class="ltr">+</code>، طول با <code class="ltr">len</code>، تغییر حروف با <code class="ltr">upper/lower</code> (برای انگلیسی)، جایگزینی با <code class="ltr">replace</code>.<br><b>خطاهای رایج این بخش:</b><br><ul><li>چسباندن متن و عدد با <code class="ltr">+</code> ⇒ <code class="ltr">TypeError</code> (باید <code class="ltr">str()</code> کنید یا جدا چاپ کنید).</li><li>فراموش کردن کوتیشن‌ها ⇒ <code class="ltr">SyntaxError</code>.</li><li>استفاده از اندیس خارج از محدوده در متن ⇒ <code class="ltr">IndexError</code>.</li></ul></div>

# %%
matn = "Python"
print(matn)
print("طول:", len(matn))
print("جایگزینی:", matn.replace("Py", "My"))
# Out:
# Python
# طول: 6
# جایگزینی: Mython

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h3 style="margin:0;">قالب‌بندی متن</h3></div><div dir="rtl" style="text-align:right; line-height:2;">برای چاپ مرتب، می‌توانیم چند مقدار را در <code class="ltr">print</code> کنار هم چاپ کنیم یا از <code class="ltr">sep</code> و <code class="ltr">end</code> استفاده کنیم.<br><b>نکته:</b> در مراحل بعد می‌توانیم سراغ قالب‌بندی‌های پیشرفته‌تر مثل <code class="ltr">f-string</code> برویم.<br></div>

# %%
name = "پوریا"
age = 24
print("نام:", name, "| سن:", age)
# Out:
# نام: پوریا | سن: 24

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">راهنمای سریع خطاها (Debugging)</h2></div><div dir="rtl" style="text-align:right; line-height:2;"><b>چطور پیام خطا را بخوانیم؟</b><br>۱) آخرین خط‌های Traceback معمولاً مهم‌ترین‌اند.<br>۲) اسم خطا را ببینید (مثل <code class="ltr">TypeError</code> یا <code class="ltr">ValueError</code>).<br>۳) شمارهٔ خط را پیدا کنید و همان‌جا را بررسی کنید.<br>۴) اگر شک دارید، با <code class="ltr">print()</code> و <code class="ltr">type()</code> مقدارها را چاپ کنید (دیباگ ساده).<br></div>

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">تمرین‌های سریع (کلاس)</h2></div><div dir="rtl" style="text-align:right; line-height:2;">۱) عدد ۱۲۳ را چاپ کنید.<br>۲) حاصل <code class="ltr">7 * 8</code> را چاپ کنید.<br>۳) دو متغیر <code class="ltr">x=10</code> و <code class="ltr">y=3</code> بسازید و <code class="ltr">x // y</code> و <code class="ltr">x % y</code> را چاپ کنید.<br>۴) یک متغیر متنی بسازید و طول آن را چاپ کنید.<br><blockquote><b>راهنمایی:</b> برای هر تمرین یک سلول کد جدا بنویسید.</blockquote></div>

# %%
# تمرین ۱
print(123)
# Out:
# 123

# %%
# تمرین ۲
print(7 * 8)
# Out:
# 56

# %%
# تمرین ۳
x = 10
y = 3
print("تقسیم صحیح:", x // y)
print("باقیمانده:", x % y)
# Out:
# تقسیم صحیح: 3
# باقیمانده: 1

# %%
# تمرین ۴
s = "هوش مصنوعی"
print("طول متن:", len(s))
# Out:
# طول متن: 10

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">تکلیف جلسه ۱ (خانه)</h2></div><div dir="rtl" style="text-align:right; line-height:2;">۱) یک برنامه بنویسید که نام و سن کاربر را بگیرد و چاپ کند (فعلاً به صورت متن چاپ شود).<br>۲) یک برنامه بنویسید که <b>قد (سانتی‌متر)</b> را بگیرد و به <b>متر</b> تبدیل کند و چاپ کند.<br>۳) یک برنامه بنویسید که سه عدد را گرفته و میانگین آن‌ها را چاپ کند.<br><blockquote><b>نکته:</b> برای تبدیل نوع از <code class="ltr">int</code> و <code class="ltr">float</code> استفاده کنید.</blockquote></div>

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h1 style="margin:0;">ادامه سرفصل‌ها — شرط‌ها و منطق</h1></div><div dir="rtl" style="text-align:right; line-height:2;"><b>هدف این بخش:</b> آماده‌سازی برای نوشتن برنامه‌های تصمیم‌گیر (شرط‌ها) و استفاده از منطق (<code class="ltr">and/or/not</code>).<br><blockquote>این قسمت ادامهٔ طبیعی جلسه ۱ است؛ اگر زمان کلاس اجازه نداد، می‌توانید در خانه مطالعه کنید و تمرین‌ها را حل کنید.</blockquote></div>

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">عملگرهای مقایسه‌ای</h2></div><div dir="rtl" style="text-align:right; line-height:2;">در شرط‌ها از عملگرهای مقایسه‌ای استفاده می‌کنیم و خروجی‌شان بولی است: <code class="ltr">True</code> یا <code class="ltr">False</code>.<br><ul><li><code class="ltr">==</code> برابر است؟</li><li><code class="ltr">!=</code> نابرابر است؟</li><li><code class="ltr">&gt;</code> بزرگ‌تر از</li><li><code class="ltr">&lt;</code> کوچک‌تر از</li><li><code class="ltr">&gt;=</code> بزرگ‌تر یا مساوی</li><li><code class="ltr">&lt;=</code> کوچک‌تر یا مساوی</li></ul><b>خطاهای رایج این بخش:</b><br><ul><li>اشتباه گرفتن <code class="ltr">=</code> (انتصاب) با <code class="ltr">==</code> (مقایسه) ⇒ معمولاً <code class="ltr">SyntaxError</code> داخل شرط.</li><li>مقایسهٔ نوع‌های ناسازگار (مثل عدد و متن) ⇒ <code class="ltr">TypeError</code>.</li><li>مقایسهٔ رشته‌ها بر اساس ترتیب حروف است؛ برای مبتدی‌ها گاهی نتیجه «عجیب» به نظر می‌رسد.</li></ul></div>

# %%
# چند مقایسهٔ ساده
print(3 == 3)
print(3 != 3)
print(10 > 7)
print(10 <= 7)

# مقایسهٔ رشته‌ها (بر اساس ترتیب حروف/کد یونیکد)
print("apple" < "banana")
# Out:
# True
# False
# True
# False
# True

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">ساختار شرطی if / elif / else</h2></div><div dir="rtl" style="text-align:right; line-height:2;">ساختار تصمیم‌گیری در پایتون با <code class="ltr">if</code>، <code class="ltr">elif</code> و <code class="ltr">else</code> نوشته می‌شود.<br><b>قانون مهم:</b> بعد از شرط باید <code class="ltr">:</code> بیاید و بدنه با تورفتگی (Indentation) مشخص می‌شود.<br><b>خطاهای رایج این بخش:</b><br><ul><li>جا انداختن <code class="ltr">:</code> ⇒ <code class="ltr">SyntaxError</code>.</li><li>تورفتگی نادرست ⇒ <code class="ltr">IndentationError</code>.</li><li>به‌جای <code class="ltr">elif</code> چند <code class="ltr">if</code> می‌نویسیم و منطق برنامه عوض می‌شود.</li></ul></div>

# %%
# مثال: تعیین وضعیت نمره
score = 67

if score >= 18:
    print("عالی ✅")
elif score >= 15:
    print("خوب 🙂")
elif score >= 10:
    print("قبول 😌")
else:
    print("مردود ❌")
# Out:
# عالی ✅

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">عملگرهای منطقی and / or / not و Truthy/Falsy</h2></div><div dir="rtl" style="text-align:right; line-height:2;">گاهی یک شرط از چند شرط کوچک‌تر ساخته می‌شود.<br><ul><li><code class="ltr">and</code>: هر دو باید درست باشند.</li><li><code class="ltr">or</code>: حداقل یکی درست باشد.</li><li><code class="ltr">not</code>: برعکس کن.</li></ul>در پایتون بعضی مقدارها «Falsy» هستند مثل <code class="ltr">0</code>، <code class="ltr">""</code>، <code class="ltr">[]</code>، <code class="ltr">{}</code>، <code class="ltr">None</code>؛ بقیه معمولاً «Truthy» حساب می‌شوند.<br><b>خطاهای رایج این بخش:</b><br><ul><li>به‌جای <code class="ltr">and/or</code> از <code class="ltr">&amp;</code> و <code class="ltr">|</code> استفاده می‌کنیم؛ این‌ها عملگرهای بیت‌به‌بیت‌اند و رفتارشان فرق دارد.</li><li>پرانتز را در شرط‌های طولانی فراموش می‌کنیم و منطق اشتباه می‌شود؛ شرط‌های پیچیده را به چند شرط ساده‌تر بشکنید.</li><li><code class="ltr">not</code> روی نتیجهٔ مقایسه گاهی نیاز به پرانتز دارد: <code class="ltr">not (x &gt; 0)</code>.</li></ul></div>

# %%
print(True and False)
print(True or False)
print(not True)

# Truthy/Falsy
print(bool(0), bool(1))
print(bool(""), bool("سلام"))
print(bool([]), bool([1, 2]))
print(bool({}), bool({"a": 1}))
# Out:
# False
# True
# False
# False True
# False True
# False True
# False True

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">تمرین‌های سریع (کلاس) — شرط و منطق</h2></div><div dir="rtl" style="text-align:right; line-height:2;">۱) یک عدد بگیر و بگو «مثبت/منفی/صفر» است.<br>۲) یک عدد بگیر و بگو «زوج/فرد» است.<br>۳) دو عدد بگیر و بزرگ‌تر را چاپ کن (اگر برابر بودند هم اعلام کن).<br>۴) یک متن بگیر؛ اگر خالی بود پیام مناسب بده، وگرنه طولش را چاپ کن.<br><blockquote><b>نکته:</b> برای ورودی عددی از <code class="ltr">int(input(...))</code> یا <code class="ltr">float(input(...))</code> استفاده کنید.</blockquote></div>

# %%
# تمرین ۱

# %%
# تمرین ۲

# %%
# تمرین ۳

# %%
# تمرین ۴

# %% [markdown]
# <div dir="rtl" style="text-align:right;"><h2 style="margin:0;">تکلیف (خانه) — شرط و منطق</h2></div><div dir="rtl" style="text-align:right; line-height:2;">۱) برنامه‌ای بنویس که سن را بگیرد و بگوید «کودک/نوجوان/بزرگسال» (حدها را خودت منطقی انتخاب کن).<br>۲) یک برنامه بنویس که سه عدد بگیرد و بزرگ‌ترین را پیدا کند (بدون استفاده از <code class="ltr">max</code>).<br>۳) یک برنامه بنویس که نام کاربر را بگیرد؛ اگر طول نام کمتر از ۳ بود هشدار بده، وگرنه سلام کند.<br></div>

# %%
# تکلیف ۱

# %%
# تکلیف ۲

# %%
# تکلیف ۳
